# %% [markdown]
# # sobel

# %%
# !wget https://learnopencv.com/wp-content/uploads/2021/06/input_image-1.jpg
# Out:
# --2024-12-26 02:36:50--  https://learnopencv.com/wp-content/uploads/2021/06/input_image-1.jpg
# Resolving learnopencv.com (learnopencv.com)... 172.66.42.215, 172.66.41.41, 2606:4700:3108::ac42:2929, ...
# Connecting to learnopencv.com (learnopencv.com)|172.66.42.215|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 38162 (37K) [image/jpeg]
# Saving to: ‘input_image-1.jpg’
#
# input_image-1.jpg   100%[===================>]  37.27K  --.-KB/s    in 0.001s
#
# 2024-12-26 02:36:50 (36.1 MB/s) - ‘input_image-1.jpg’ saved [38162/38162]

# %%
import cv2

# Read the original image
img = cv2.imread('/content/input_image-1.jpg')
# Display original image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x640>

# %%
# Convert to graycsale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=960x640>

# %%
# Blur the image for better edge detection
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
cv2_imshow(img_blur)
# Out:
# <PIL.Image.Image image mode=L size=960x640>

# %% [markdown]
# sobel edge

# %%
sobelx = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=0, ksize=5) # Sobel Edge Detection on the X axis
cv2_imshow(sobelx)
# Out:
# <PIL.Image.Image image mode=L size=960x640>

# %%
sobely = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=0, dy=1, ksize=5) # Sobel Edge Detection on the Y axis
cv2_imshow(sobely)
# Out:
# <PIL.Image.Image image mode=L size=960x640>

# %%
sobelxy = cv2.Sobel(src=img_blur, ddepth=cv2.CV_64F, dx=1, dy=1, ksize=5) # Combined X and Y Sobel Edge Detection
cv2_imshow( sobelxy)
# Out:
# <PIL.Image.Image image mode=L size=960x640>

# %% [markdown]
# # canny

# %%
# Canny Edge Detection
edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=960x640>
