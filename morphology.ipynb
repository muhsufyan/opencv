# %% [markdown]
# # erosi

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/refs/heads/4.x/doc/py_tutorials/py_imgproc/py_morphological_ops/images/j.png
# Out:
# --2024-12-25 13:58:59--  https://raw.githubusercontent.com/opencv/opencv/refs/heads/4.x/doc/py_tutorials/py_imgproc/py_morphological_ops/images/j.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1126 (1.1K) [image/png]
# Saving to: ‘j.png’
#
# j.png               100%[===================>]   1.10K  --.-KB/s    in 0s
#
# 2024-12-25 13:58:59 (49.3 MB/s) - ‘j.png’ saved [1126/1126]

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

img = cv.imread('j.png', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
plt.imshow(img, cmap="grey")

# %%
kernel = np.ones((5,5),np.uint8)
plt.imshow(kernel, cmap="grey")

# %%
erosion = cv.erode(img,kernel,iterations = 1)
plt.imshow(erosion, cmap="grey")

# %% [markdown]
# # dilation

# %%
dilation = cv.dilate(img,kernel,iterations = 1)
plt.imshow(dilation, cmap="grey")

# %%
gradient = cv.morphologyEx(img, cv.MORPH_GRADIENT, kernel)
plt.imshow(gradient, cmap="grey")

# %%
tophat = cv.morphologyEx(img, cv.MORPH_TOPHAT, kernel)
plt.imshow(tophat, cmap="grey")

# %%
blackhat = cv.morphologyEx(img, cv.MORPH_BLACKHAT, kernel)
plt.imshow(blackhat, cmap="grey")

# %%
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
plt.imshow(opening, cmap="grey")

# %%
# !wget https://b2633864.smushcdn.com/2633864/wp-content/uploads/2021/04/opencv_morphological_ops_pyimagesearch_logo_noise.png
# Out:
# --2024-12-25 14:14:22--  https://b2633864.smushcdn.com/2633864/wp-content/uploads/2021/04/opencv_morphological_ops_pyimagesearch_logo_noise.png
# Resolving b2633864.smushcdn.com (b2633864.smushcdn.com)... 84.17.46.53, 2400:52e0:1e01::879:1
# Connecting to b2633864.smushcdn.com (b2633864.smushcdn.com)|84.17.46.53|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://pyimagesearch.com/wp-content/uploads/2021/04/opencv_morphological_ops_pyimagesearch_logo_noise.png [following]
# --2024-12-25 14:14:23--  https://pyimagesearch.com/wp-content/uploads/2021/04/opencv_morphological_ops_pyimagesearch_logo_noise.png
# Resolving pyimagesearch.com (pyimagesearch.com)... 45.33.87.127
# Connecting to pyimagesearch.com (pyimagesearch.com)|45.33.87.127|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2775 (2.7K) [image/png]
# Saving to: ‘opencv_morphological_ops_pyimagesearch_logo_noise.png’
#
# ...

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('opencv_morphological_ops_pyimagesearch_logo_noise.png', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
plt.imshow(img, cmap="grey")

# %%
kernel = np.ones((5,5),np.uint8)
opening = cv.morphologyEx(img, cv.MORPH_OPEN, kernel)
plt.imshow(opening, cmap="grey")

# %%
# !wget https://docs.opencv.org/4.x/closing.png
# Out:
# --2024-12-25 14:21:32--  https://docs.opencv.org/4.x/closing.png
# Resolving docs.opencv.org (docs.opencv.org)... 104.26.15.224, 104.26.14.224, 172.67.72.85, ...
# Connecting to docs.opencv.org (docs.opencv.org)|104.26.15.224|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1003 [image/png]
# Saving to: ‘closing.png’
#
# closing.png         100%[===================>]    1003  --.-KB/s    in 0s
#
# 2024-12-25 14:21:32 (13.7 MB/s) - ‘closing.png’ saved [1003/1003]

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img = cv.imread('/content/closing.png', cv.IMREAD_GRAYSCALE)
assert img is not None, "file could not be read, check with os.path.exists()"
plt.imshow(img, cmap="grey")

# %%
kernel = np.ones((5,5),np.uint8)
closing = cv.morphologyEx(img, cv.MORPH_CLOSE, kernel)
plt.imshow(closing, cmap="grey")
