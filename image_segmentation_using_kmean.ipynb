# %%
# !wget https://machinelearningknowledge.ai/wp-content/uploads/2021/09/image.jpg
# Out:
# --2024-12-26 04:57:15--  https://machinelearningknowledge.ai/wp-content/uploads/2021/09/image.jpg
# Resolving machinelearningknowledge.ai (machinelearningknowledge.ai)... 172.67.207.218, 104.21.22.239, 2606:4700:3037::ac43:cfda, ...
# Connecting to machinelearningknowledge.ai (machinelearningknowledge.ai)|172.67.207.218|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/webp]
# Saving to: ‘image.jpg’
#
# image.jpg               [ <=>                ]  42.88K  --.-KB/s    in 0.001s
#
# 2024-12-26 04:57:15 (41.4 MB/s) - ‘image.jpg’ saved [43910]

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
sample_image = cv2.imread('image.jpg')
img = cv2.cvtColor(sample_image,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# pada kasus ini, asalnya gambar berukuran (500,800,3) yang merupakan width, height, channels

# %%
img.shape
# Out:
# (500, 800, 3)

# %% [markdown]
# lalu ubah gambar jadi 2 dimensi yaitu (400000, 3) dimana 400000 didapat dari 500x800

# %%
twoDimage = img.reshape((-1,3))
print(twoDimage.shape)
twoDimage = np.float32(twoDimage)
# Out:
# (400000, 3)

# %% [markdown]
# setting parameter untuk kmean

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
K = 2 # 2 cluster
attempts=10 # 10 kali percobaan

# %% [markdown]
# jalankan kmean ke gambar

# %%
ret,label,center=cv2.kmeans(twoDimage,K,None,criteria,attempts,cv2.KMEANS_PP_CENTERS)
center = np.uint8(center)
res = center[label.flatten()]
result_image = res.reshape((img.shape))

plt.axis('off')
plt.imshow(result_image)
